# %% [markdown]
# # SET 1

# %% [markdown]
# ### 1. Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2
#
# Name of company	  Measure X \
# Allied Signal	    24.23% \
# Bankers Trust	    25.53% \
# General Mills	25.41% \
# ITT Industries	24.14%\
# J.P.Morgan & Co.	29.62%\
# Lehman Brothers	28.25%\
# Marriott	25.81%\
# MCI	24.39%\
# Merrill Lynch	40.26%\
# Microsoft	32.95%\
# Morgan Stanley	91.36%\
# Sun Microsystems	25.99%\
# Travelers	39.42%\
# US Airways	26.71%\
# Warner-Lambert	35.00%\

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

companies = [    'Allied Signal', 'Bankers Trust', 'General Mills', 'ITT Industries',    'J.P.Morgan & Co.', 'Lehman Brothers', 'Marriott', 'MCI',    'Merrill Lynch', 'Microsoft', 'Morgan Stanley', 'Sun Microsystems',    'Travelers', 'US Airways', 'Warner-Lambert']

measure_x = [    24.23, 25.53, 25.41, 24.14, 29.62, 28.25, 25.81, 24.39,40.26, 32.95, 91.36, 25.99, 39.42, 26.71, 35.00]

plt.figure(figsize=(12, 6))
plt.bar(companies, measure_x)
plt.xticks(rotation=90)
plt.xlabel('Company')
plt.ylabel('Measure X')
plt.title('Measure X for Different Companies')
plt.tight_layout()
plt.show()

# %%
# Create the box plot
plt.boxplot(measure_x)
plt.xlabel('Measure X')
plt.ylabel('Value')
plt.title('Box Plot - Measure X')
plt.show()

# %%
import numpy as np

data = np.array(measure_x)

# Find outliers using the interquartile range (IQR) method
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = data[(data < lower_bound) | (data > upper_bound)]

# Calculate mean, standard deviation, and variance
mean = np.mean(data)
std_dev = np.std(data)
variance = np.var(data)

print("Outliers:", outliers)
print("Mean (μ):", mean)
print("Standard Deviation (σ):", std_dev)
print("Variance (σ^2):", variance)
# Out:
# Outliers: [91.36]
# Mean (μ): 33.27133333333333
# Standard Deviation (σ): 16.370812590976932
# Variance (σ^2): 268.00350488888887

# %% [markdown]
# ## question 4

# %%
n = 5
p = 1/200
q = 1 - p

probability = 1 - (q**n)
print("Probability of at least one misdirected call:", probability)
# Out:
# Probability of at least one misdirected call: 0.02475124687812502

# %% [markdown]
# ## question 5 (iii)

# %%
outcomes = [-2000, -1000, 0, 1000, 2000, 3000]
probabilities = [0.1, 0.1, 0.2, 0.2, 0.3, 0.1]

average_earnings = sum([outcomes[i] * probabilities[i] for i in range(len(outcomes))])
print("Long-term average earnings:", average_earnings)
# Out:
# Long-term average earnings: 800.0

# %% [markdown]
# ## question 5 (iv)

# %%
mean = average_earnings
variance = sum([(outcomes[i] - mean)**2 * probabilities[i] for i in range(len(outcomes))])
standard_deviation = variance**0.5
print("Risk measure (standard deviation):", standard_deviation)
# Out:
# Risk measure (standard deviation): 1469.6938456699068

# %% [markdown]
# # set 2

# %% [markdown]
# ## question 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Parameters
mu = 10
sigma = 2

# Generate random samples for X1 and X2
np.random.seed(42)
X1 = np.random.normal(mu, sigma, 1000)
X2 = np.random.normal(mu, sigma, 1000)

# Compute 2X1 and X1 + X2
two_X1 = 2 * X1
X1_plus_X2 = X1 + X2
X1_minus_X2 = X1 - X2

# Plot the distributions
plt.figure(figsize=(12, 4))

plt.subplot(131)
plt.hist(two_X1, bins=30, density=True, alpha=0.7)
plt.title("Distribution of 2X1")
plt.xlabel("Value")
plt.ylabel("Density")

plt.subplot(132)
plt.hist(X1_plus_X2, bins=30, density=True, alpha=0.7)
plt.title("Distribution of X1 + X2")
plt.xlabel("Value")
plt.ylabel("Density")

plt.subplot(133)
plt.hist(X1_minus_X2, bins=30, density=True, alpha=0.7)
plt.title("Distribution of X1 - X2")
plt.xlabel("Value")
plt.ylabel("Density")

plt.tight_layout()
plt.show()

# Print the parameters
print("Parameters:")
print("Mean and Variance of 2X1: mean =", np.mean(two_X1), ", variance =", np.var(two_X1))
print("Mean and Variance of X1 + X2: mean =", np.mean(X1_plus_X2), ", variance =", np.var(X1_plus_X2))
print("Mean and Variance of X1 - X2: mean =", np.mean(X1_minus_X2), ", variance =", np.var(X1_minus_X2))
# Out:
# Parameters:
# Mean and Variance of 2X1: mean = 20.077328223289303 , variance = 15.326479835704275
# Mean and Variance of X1 + X2: mean = 20.180336586142964 , variance = 7.4919409722853985
# Mean and Variance of X1 - X2: mean = -0.10300836285366083 , variance = 8.122661500890676

# %% [markdown]
# ## question 4

# %%
import scipy.stats as stats

mean = 100
std_dev = 20

# Calculate the z-scores corresponding to the lower and upper probabilities
lower_prob = (1 - 0.99) / 2
upper_prob = 1 - lower_prob
z_lower = stats.norm.ppf(lower_prob)
z_upper = stats.norm.ppf(upper_prob)

# Calculate the values of a and b
a = mean + (z_lower * std_dev)
b = mean + (z_upper * std_dev)

a, b
# Out:
# (48.48341392902199, 151.516586070978)

# %% [markdown]
# ## question 5

# %%
# Combine Mean Profit of both division for Company= mean1 + mean2
mean1 = 5
mean2 = 7
Mean = (mean1+mean2) # 1 USD = 45 rupees
print('The Mean Profit of both division:',Mean, 'Million$')
print('The Mean Profit of both division:',(Mean*45)/10, 'Crore Rupees')

# Combine standard Deviation = (Std1^2 + Std2^2)^1/2
std1 = 3**2
std2 = 4**2
Std = np.sqrt(std1 + std2)
print('The Standard Deviation of both division:', Std, 'Million$')
print('The Standard Deviation of both division:', (Std*45)/10, 'Crore Rupees')
# Out:
# The Mean Profit of both division: 12 Million$
# The Mean Profit of both division: 54.0 Crore Rupees
# The Standard Deviation of both division: 5.0 Million$
# The Standard Deviation of both division: 22.5 Crore Rupees

# %% [markdown]
#  A. Specify a Rupee range (centered on the mean) such that it contains 95% probability for the annual profit of the company.

# %%
r1, r2 = np.round(stats.norm.interval(0.95, Mean, Std),2)
print('Rupee Ranges from',r1,'to',r2,'Million$ in Annual profit of the Company 95% of the time')
print('Rupee Ranges from',np.divide(np.multiply(r1,45),10),'to',np.divide(np.multiply(r2,45),10),'Crore Rupees in Annual profit of the Company 95% of the time')
# Out:
# Rupee Ranges from 2.2 to 21.8 Million$ in Annual profit of the Company 95% of the time
# Rupee Ranges from 9.900000000000002 to 98.1 Crore Rupees in Annual profit of the Company 95% of the time

# %% [markdown]
# B.	Specify the 5th percentile of profit (in Rupees) for the company

# %%
# Z value  = X_bar - Mew / Std pop 
# for percentile, X_percentile = (Zvalue * Std pop) + Mew
Z_05_ = stats.norm.ppf(0.05)
Fifth_percentile = (Z_05_ * Std) + Mean
print('The 5th percentile of Profit for the company is',np.round(Fifth_percentile,2),'Million$')
print('The 5th percentile of Profit for the company is',np.round((Fifth_percentile*45)/10,),'Crore Rupees')
# Out:
# The 5th percentile of Profit for the company is 3.78 Million$
# The 5th percentile of Profit for the company is 17.0 Crore Rupees

# %% [markdown]
# C.	Which of the two divisions has a larger probability of making a loss in a given year?

# %%
# The probability of Division #1 making a loss
print('The Probability of Division #1 making a loss is',np.round((stats.norm.cdf(0,5,3))*100,2),'%')

# The probability of Division #2 making a loss
print('The Probability of Division #2 making a loss is',np.round((stats.norm.cdf(0,7,4))*100,2),'%')

Division_1 = (stats.norm.cdf(0,5,3))*100
Division_2 = (stats.norm.cdf(0,7,4))*100

if Division_1>Division_2:
    print('The Division 1 has a larger Probability of making a loss')
else:
          print('The Division 2 has a larger Porbability of making a loss')
# Out:
# The Probability of Division #1 making a loss is 4.78 %
# The Probability of Division #2 making a loss is 4.01 %
# The Division 1 has a larger Probability of making a loss

# %% [markdown]
# # SET 3

# %% [markdown]
# # SET 4

# %%
from scipy.stats import norm

sample_mean = 50
sample_std = 40
sample_size = 100

lower_threshold = 45
upper_threshold = 55

# Calculate the standard error of the mean
se = sample_std / (sample_size ** 0.5)

# Calculate the z-scores for the lower and upper thresholds
z_lower = (lower_threshold - sample_mean) / se
z_upper = (upper_threshold - sample_mean) / se

# Calculate the probability of an investigation (area outside the desired range)
probability_investigation = norm.cdf(z_lower) + (1 - norm.cdf(z_upper))

print("Probability of an investigation:", probability_investigation)
# Out:
# Probability of an investigation: 0.2112995473337107
